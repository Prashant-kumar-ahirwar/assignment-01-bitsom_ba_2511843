# %%
import pandas as pd

# %%
df = pd.read_csv('E:\\massai/\codes\\python\\assignmet 2.0\\datasets\\orders_flat.csv')
df.head(2)
# Out:
#   order_id customer_id customer_name   customer_email customer_city  \
# 0  ORD1027        C002  Priya Sharma  priya@gmail.com         Delhi
# 1  ORD1114        C001   Rohan Mehta  rohan@gmail.com        Mumbai
#
#   product_id product_name    category  unit_price  quantity  order_date  \
# 0       P004     Notebook  Stationery         120         4  2023-11-02
# 1       P007      Pen Set  Stationery         250         2  2023-08-06
#
#   sales_rep_id sales_rep_name  sales_rep_email  \
# 0         SR02    Anita Desai   anita@corp.com
# 1         SR01   Deepak Joshi  deepak@corp.com
#
#                                       office_address
# 0  Delhi Office, Connaught Place, New Delhi - 110001
# 1          Mumbai HQ, Nariman Point, Mumbai - 400021

# %%
df.shape
# Out:
# (186, 15)

# %%
df['product_id'].is_unique
# Out:
# False

# %%
df.dtypes
# Out:
# order_id             str
# customer_id          str
# customer_name        str
# customer_email       str
# customer_city        str
# product_id           str
# product_name         str
# category             str
# unit_price         int64
# quantity           int64
# order_date           str
# sales_rep_id         str
# sales_rep_name       str
# sales_rep_email      str
# office_address       str
# dtype: object

# %% [markdown]
# -- Q1: List all customers from Mumbai along with their total order value
# -- Q2: Find the top 3 products by total quantity sold
# -- Q3: List all sales representatives and the number of unique customers they have handled
# -- Q4: Find all orders where the total value exceeds 10,000, sorted by value descending
# -- Q5: Identify any products that have never been ordered
